# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import requests 
from StringIO import StringIO
import numpy as np
import pandas as pd # pandas
import matplotlib.pyplot as plt # module for plotting 
import datetime as dt # module for manipulating dates and times
import numpy.linalg as lin # module for performing linear algebra operations

# %%
# get food prices tsv object
url = "http://api.qdatum.io/v1/pull/7?format=tsv"
info = pd.read_csv(url, sep='\t')

# %%
info.head()
# Out:
#    pos  adm0_id adm0_name  adm1_id adm1_name  mkt_id mkt_name  cm_id cm_name  \
# 0    2      106    Guinea    40700      Boke    1639     Boke     50   Beans
# 1    3      106    Guinea    40700      Boke    1639     Boke     50   Beans
# 2    4      106    Guinea    40700      Boke    1639     Boke     50   Beans
# 3    5      106    Guinea    40700      Boke    1639     Boke     50   Beans
# 4    6      106    Guinea    40700      Boke    1639     Boke     50   Beans
#
#    cur_id   ...   um_id  um_name month_year  mp_month mp_year  mp_price  \
# 0      54   ...       5       KG      41913        10    2014      6500
# 1      54   ...       5       KG      41883         9    2014      6500
# 2      54   ...       5       KG      41852         8    2014      6500
# 3      54   ...       5       KG      41821         7    2014      4000
# 4      54   ...       5       KG      41791         6    2014      4000
#
#    mp_commoditysource  sdr_id  sdr_name sdr_level
# 0                 WFP       1      Boke      ADM1
# 1                 WFP       1      Boke      ADM1
# 2                 WFP       1      Boke      ADM1
# 3                 WFP       1      Boke      ADM1
# 4                 WFP       1      Boke      ADM1
#
# [5 rows x 23 columns]

# %%
countries = info.drop_duplicates('adm0_name').adm0_name

countries
# Out:
# 0              Guinea
# 1106          Liberia
# 4157             Mali
# 26559    Sierra Leone
# Name: adm0_name, dtype: object
