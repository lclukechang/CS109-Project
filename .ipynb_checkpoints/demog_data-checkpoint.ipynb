# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import requests 
from StringIO import StringIO
import numpy as np
import pandas as pd # pandas
import matplotlib.pyplot as plt # module for plotting 
import datetime as dt # module for manipulating dates and times
import numpy.linalg as lin # module for performing linear algebra operations

# %%
# get demographics tsv object
url = "http://api.qdatum.io/v1/pull/6?format=tsv"
info = pd.read_csv(url, sep='\t')

# see what countries are being used
countries = info.drop_duplicates('country').country
len(countries)
# -> 8

countries
# 0     Cote d'Ivoire
# 13           Guinea
# 24           Gambia
# 35    Guinea Bissau
# 47          Liberia
# 65             Mali
# 74          Senegal
# 87     Sierra Leone
# Out:
# 0     Cote d'Ivoire
# 13           Guinea
# 24           Gambia
# 35    Guinea Bissau
# 47          Liberia
# 65             Mali
# 74          Senegal
# 87     Sierra Leone
# Name: country, dtype: object

# %%
# Total regional information
tot_region = info[(info.region == 'Total')]
tot_region
# Out:
#     pos country_code iso_code        country  year gdlcode region   iwi  edyr  \
# 0     2          NaN      CIV  Cote d'Ivoire  2011    CIVt  Total  47.0   4.2
# 13   15           GN      GIN         Guinea  2012    GINt  Total  38.1   3.5
# 24   26           GM      GMB         Gambia  2006    GMBt  Total  44.4   4.3
# 35   37          NaN      GNB  Guinea Bissau  2006    GNBt  Total  28.1   3.1
# 47   49           LR      LBR        Liberia  2013    LBRt  Total  30.9   5.8
# 65   67           ML      MLI           Mali  2013    MLIt  Total  35.2   2.1
# 74   76           SN      SEN        Senegal  2011    SENt  Total  51.7   3.2
# 87   89           SL      SLE   Sierra Leone  2013    SLEt  Total  26.9   3.7
#
#     edyr_fem    ...     age5059  age6069  age7079 age8089 age90hi   N  Nhh  \
# 0        3.2    ...         5.6      3.4      1.5     0.5     0.1 NaN  NaN
# 13       2.2    ...         6.3      4.3      2.0     0.7     0.1 NaN  NaN
# 24       3.1    ...         5.9      3.1      1.5     0.6     0.1 NaN  NaN
# 35       2.1    ...         5.2      3.1      1.3     0.5     0.1 NaN  NaN
# 47       4.3    ...         5.8      3.1      1.5     0.6     0.2 NaN  NaN
# 65       1.5    ...         6.1      3.8      1.3     0.4     0.2 NaN  NaN
# 74       2.6    ...         6.1      3.3      2.2     0.7     0.2 NaN  NaN
# 87       2.7    ...         5.3      4.0      2.0     0.6     0.1 NaN  NaN
#
#     sdr_id  sdr_name  sdr_level
# 0        0       NaN        NaN
# 13       0       NaN        NaN
# 24       0       NaN        NaN
# 35       0       NaN        NaN
# 47       0       NaN        NaN
# 65       0       NaN        NaN
# 74       0       NaN        NaN
# 87       0       NaN        NaN
#
# [8 rows x 41 columns]
